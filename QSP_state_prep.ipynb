# %%
# !pip install cirq
# Out:
# Collecting cirq
#   Downloading cirq-1.3.0-py3-none-any.whl (8.1 kB)
# Collecting cirq-core==1.3.0
#   Downloading cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 17.9 MB/s eta 0:00:01
# Collecting cirq-rigetti==1.3.0
#   Downloading cirq_rigetti-1.3.0-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 18.1 MB/s eta 0:00:01
# Collecting cirq-ionq==1.3.0
#   Downloading cirq_ionq-1.3.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 34.5 MB/s eta 0:00:01
# Collecting cirq-web==1.3.0
#   Downloading cirq_web-1.3.0-py3-none-any.whl (596 kB)
#      |████████████████████████████████| 596 kB 59.9 MB/s eta 0:00:01
# Collecting cirq-ft==1.3.0
#   Downloading cirq_ft-1.3.0-py3-none-any.whl (143 kB)
#      |████████████████████████████████| 143 kB 75.4 MB/s eta 0:00:01
# Collecting cirq-pasqal==1.3.0
#   Downloading cirq_pasqal-1.3.0-py3-none-any.whl (31 kB)
# Collecting cirq-aqt==1.3.0
#   Downloading cirq_aqt-1.3.0-py3-none-any.whl (27 kB)
# Collecting cirq-google==1.3.0
#   Downloading cirq_google-1.3.0-py3-none-any.whl (598 kB)
#      |████████████████████████████████| 598 kB 26.9 MB/s eta 0:00:01
# Requirement already satisfied: requests~=2.18 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-aqt==1.3.0->cirq) (2.26.0)
# Requirement already satisfied: sortedcontainers~=2.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (2.4.0)
# Requirement already satisfied: tqdm in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (4.62.3)
# Requirement already satisfied: networkx>=2.4 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (2.6.3)
# Requirement already satisfied: numpy~=1.16 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.20.3)
# Requirement already satisfied: scipy in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.7.1)
# Requirement already satisfied: matplotlib~=3.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (3.4.3)
# Requirement already satisfied: pandas in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.3.4)
# Collecting duet~=0.2.8
#   Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Requirement already satisfied: sympy in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.9)
# Collecting typing-extensions>=4.2
#   Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 9.9 MB/s  eta 0:00:01
# Collecting cachetools>=5.3
#   Downloading cachetools-6.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (21.2.0)
# Requirement already satisfied: nbformat in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (5.1.3)
# Requirement already satisfied: nbconvert in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (6.1.0)
# Requirement already satisfied: ipywidgets in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (7.6.5)
# Collecting google-api-core[grpc]>=1.14.0
#   Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 128.1 MB/s eta 0:00:01
# Collecting proto-plus>=1.20.0
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 32.1 MB/s eta 0:00:01
# Collecting protobuf>=3.15.0
#   Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
#      |████████████████████████████████| 425 kB 112.7 MB/s eta 0:00:01
# Collecting pyquil<4.0.0,>=3.2.0
#   Downloading pyquil-3.5.4-py3-none-any.whl (223 kB)
#      |████████████████████████████████| 223 kB 83.7 MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 117.1 MB/s eta 0:00:01
# Collecting google-auth<3.0.0,>=2.14.1
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 130.7 MB/s eta 0:00:01
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.73.1-py3-none-any.whl (14 kB)
# Collecting grpcio<2.0.0,>=1.33.2
#   Downloading grpcio-1.73.1.tar.gz (12.7 MB)
#      |████████████████████████████████| 12.7 MB 32.1 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 129.1 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting cachetools>=5.3
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (0.10.0)
# Requirement already satisfied: six in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.16.0)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 10.9 MB/s  eta 0:00:01
# Collecting types-retry<0.10.0,>=0.9.9
#   Downloading types_retry-0.9.9.20250322-py3-none-any.whl (7.7 kB)
# Collecting lark<0.12.0,>=0.11.1
#   Downloading lark-0.11.3.tar.gz (229 kB)
#      |████████████████████████████████| 229 kB 8.2 MB/s eta 0:00:01
# Collecting tenacity<9.0.0,>=8.2.2
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting numpy~=1.16
#   Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 34.2 MB/s eta 0:00:01
# Collecting types-deprecated<2.0.0.0,>=1.2.9.2
#   Downloading types_deprecated-1.2.15.20250304-py3-none-any.whl (8.6 kB)
# Collecting types-python-dateutil<3.0.0,>=2.8.19
#   Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Collecting qcs-api-client<0.22.0,>=0.21.0
#   Downloading qcs_api_client-0.21.6-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 74.3 MB/s eta 0:00:01
# Collecting rpcq<4.0.0,>=3.10.0
#   Downloading rpcq-3.11.0.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 21.2 MB/s eta 0:00:01
# Collecting deprecated<2.0.0,>=1.2.13
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from deprecated<2.0.0,>=1.2.13->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.12.1)
# Collecting retrying<2.0.0,>=1.3.3
#   Downloading retrying-1.4.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pydantic<2.0.0,>=1.7.2 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.7.3)
# Collecting attrs
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 38.2 MB/s eta 0:00:01
# Collecting httpx<0.24.0,>=0.23.0
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 49.5 MB/s  eta 0:00:01
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.10.2)
# Collecting rfc3339<7.0,>=6.2
#   Downloading rfc3339-6.2-py3-none-any.whl (5.5 kB)
# Collecting iso8601<2.0.0,>=1.0.2
#   Downloading iso8601-1.1.0-py3-none-any.whl (9.9 kB)
# Collecting PyJWT<3.0.0,>=2.4.0
#   Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 47.2 MB/s  eta 0:00:01
# Requirement already satisfied: sniffio in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.2.0)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2021.10.8)
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 58.9 MB/s eta 0:00:01
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: idna>=2.8 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (3.2)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.3.0->cirq) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.3.0->cirq) (1.26.7)
# Requirement already satisfied: msgpack<2.0,>=0.6 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.0.2)
# Collecting python-rapidjson
#   Downloading python_rapidjson-1.20-cp39-cp39-macosx_10_9_x86_64.whl (229 kB)
#      |████████████████████████████████| 229 kB 51.1 MB/s eta 0:00:01
# Requirement already satisfied: pyzmq>=17 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (22.2.1)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 152.6 MB/s eta 0:00:01
# Collecting numpy~=1.16
#   Downloading numpy-1.22.4-cp39-cp39-macosx_10_15_x86_64.whl (17.7 MB)
#      |████████████████████████████████| 17.7 MB 505 kB/s eta 0:00:01
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (7.29.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (6.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (5.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (6.1)
# Requirement already satisfied: appnope in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (1.4.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (4.8.0)
# Requirement already satisfied: decorator in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (5.1.0)
# Requirement already satisfied: backcall in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.7.5)
# Requirement already satisfied: pygments in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (58.0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (4.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbformat->cirq-ft==1.3.0->cirq) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->cirq-ft==1.3.0->cirq) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (6.4.5)
# Requirement already satisfied: jinja2 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.14.6)
# Requirement already satisfied: pycparser in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.1.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (1.4.3)
# Requirement already satisfied: testpath in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.5.0)
# Requirement already satisfied: defusedxml in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.3)
# Requirement already satisfied: bleach in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.8.4)
# Requirement already satisfied: async-generator in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->cirq-ft==1.3.0->cirq) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->cirq-ft==1.3.0->cirq) (1.5.1)
# Requirement already satisfied: webencodings in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->cirq-ft==1.3.0->cirq) (0.5.1)
# Requirement already satisfied: packaging in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->cirq-ft==1.3.0->cirq) (21.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from pandas->cirq-core==1.3.0->cirq) (2021.3)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.12.tar.gz (225 kB)
#      |████████████████████████████████| 225 kB 77.7 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: mpmath>=0.19 in /Users/gabewaite/opt/anaconda3/lib/python3.9/site-packages (from sympy->cirq-core==1.3.0->cirq) (1.2.1)
# Building wheels for collected packages: grpcio, lark, rpcq, ruamel.yaml.clib
#   Building wheel for grpcio (setup.py) ... /^C

# %%
import cirq
def controlledRySequence(
    ancilla_qb: cirq.Qid,
    workspace_qbs: list[cirq.Qid],
    n: int
) -> cirq.Circuit:
    """
    Implements a unitary with controlled Ry rotations and a final X gate on an ancilla.

    Args:
        ancilla_qb: The ancilla qubit.
        workspace_qbs: A list of n workspace qubits (x_1, ..., x_n).
        n: The number of workspace registers. This should be equal to len(workspace_qbs).

    Returns:
        A cirq.Circuit implementing the specified unitary.
    Note:
        This is the block encoding we want
    """
    if len(workspace_qbs) != n:
        raise ValueError(f"Number of workspace qubits ({len(workspace_qbs)}) must equal n ({n}).")

    # Initialise the circuit
    circuit = cirq.Circuit()

    # Apply controlled Ry rotations
    for j in range(n):
        # cirq.ry(rads) equivalent exp(-i Y rads / 2) = cos(rads/2) I - i sin(rads/2) Y

        theta_j = (2**(j + 1)) / (2**n)

        # Apply the controlled Ry gate
        # The control is workspace_qbs[j], target is ancilla_qb
        circuit.append(cirq.ry(theta_j).on(ancilla_qb).controlled_by(workspace_qbs[j]))

    # Finally, apply a bit flip gate X to the ancilla register
    circuit.append(cirq.X(ancilla_qb))

    return circuit

# %%
# Define qubits
ancilla = cirq.NamedQubit('ancilla')
workspace = [cirq.NamedQubit(f'x_{i}') for i in range(1, 4)]
qubits = [ancilla] + workspace

# Define the circuit with 3 workspace qubits
example_circuit = controlledRySequence(ancilla, workspace, 3)
# Print the circuit
print("Example Circuit:")
print(example_circuit)
print("*"*20)

# Initialise the simulator
simulator = cirq.Simulator()

# Simulate the circuit to get output state
result = simulator.simulate(example_circuit, qubit_order=qubits)

# Print the final state vector
outout_sv = result.final_state_vector
print("Final State Vector:")
print(circ.dirac_notation(outout_sv, qubits))
# print(example_circuit)

# %% [markdown]
# Where *should* the amplitudes lie?

# %%
from matplotlib import pyplot as plt
import numpy as np

def StateVecAmpGraph(sigma: float, num_qbs: int):
  amp_x_data = np.arange(2**num_qbs)
  sv_amplitudes = [float(targ_func(x,sigma,num_qbs)) for x in amp_x_data]

  func_x_data = np.linspace(0,2**num_qbs,50)
  plt.plot(amp_x_data, sv_amplitudes, 'o', color='red', label='Statevector amplitudes')
  plt.plot(func_x_data, [targ_func(x,sigma,num_qbs) for x in func_x_data], color='blue', label=f'g(x) for σ={sigma}')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.show()

# %% [markdown]
# Let's define a custom cirq gate corresponding the the block encoded rotation sequence above.

# %%
class ControlledRySequenceGate(cirq.Gate):
    """
    A custom gate for the controlledRySequence circuit.
    This gate implements a controlled Ry rotation sequence followed by an X gate on an ancilla qubit.
    """

    def __init__(self, num_workspace_qubits: int):
        if num_workspace_qubits < 0:
            raise ValueError("Number of workspace qubits must be non-negative.")
        self._num_workspace_qubits = num_workspace_qubits
        self._total_qubits = 1 + num_workspace_qubits # Define total qubits.

    def _num_qubits_(self) -> int:
        return self._total_qubits

    def _decompose_(self, qubits):
        if len(qubits) != self._total_qubits:
            raise ValueError(f"Expected {self._total_qubits} qubits, but got {len(qubits)}.")

        ancilla_qb = qubits[0]
        workspace_qbs = list(qubits[1:])

        composed_circuit = controlledRySequence(
            ancilla_qb = ancilla_qb,
            workspace_qbs = workspace_qbs,
            n = self._num_workspace_qubits
        )
        yield composed_circuit.all_operations()

    def _circuit_diagram_info_(self, args: cirq.CircuitDiagramInfoArgs):
        return cirq.CircuitDiagramInfo(
            wire_symbols=("U",) * self._total_qubits,
            connected=True,
        )

    def __eq__(self, other):
        if not isinstance(other, type(self)):
            return NotImplemented
        return self._num_workspace_qubits == other._num_workspace_qubits

    def __repr__(self):
        return f"ControlledRySequenceGate(num_workspace_qubits={self._num_workspace_qubits})"

# %% [markdown]
# Now we can construct the state preparation circuit using the angle list and the custom gate.

# %%
def StatePreparation(num_ws_qbs: int, angle_list: list):
    """
    Implements the state preparation circuit using QSP with controlled Ry rotations.
    Args:
        sigma (float): The parameter for the target function.
        num_ws_qbs (int): The number of workspace qubits.
        angle_list (list): A list of angles for the QSP rotations.
    Returns:
        cirq.Circuit: The circuit implementing the state preparation.
    """
    n = num_ws_qbs # Number of workspace qubits

    # Setup circuit qubits
    ancilla = [cirq.NamedQubit(f'{desc}_anc') for desc in ['qsp','rbe']] # quantum signal processing ancilla and rotation block encoding ancilla
    workspace = [cirq.NamedQubit(f'x_{i}') for i in range(1,n+1)]

    # Initialise the circuit
    circuit = cirq.Circuit()
    # Hadamard on first ancilla and all workspace
    circuit.append(cirq.H(ancilla[0]))
    circuit.append(cirq.H.on_each(workspace))

    # cirq.rz(rads) is equivalent to 
    #  exp(-i Z rads / 2) = cos(rads/2) I - i sin(rads/2) Z
    #                     | 
    #                     = [[exp(-i rads/2), 0], [0, exp(i rads/2)]]
    # Define QSP operator
    #   qsp_op = [[np.exp(1j * phi), 0.], [0., np.exp(-1j * phi)]]

    # Apply first QSP operator on first ancilla
    phi_0 = angle_list[0]
    circuit.append(cirq.rz(-2 * phi_0).on(ancilla[0]))


    my_custom_gate = ControlledRySequenceGate(num_workspace_qubits=n)
    be_qbs = [ancilla[1]] + workspace
    # Apply RZ rotations for phi in the list from 1 onwards.
    # Between each rotation, do a controlled unitary BE.
    for phi in angle_list[1:]:
        circuit.append(my_custom_gate.on(*be_qbs).controlled_by(ancilla[0]))
        circuit.append(cirq.rz(-2 * phi).on(ancilla[0]))

    return circuit

# %%
# We can now consider a dummy scenario.
# We need to import our jupyter notebook (coeff_finder.ipynb) as a module.

from coeff_finder import Alt_DegreeFromError, GetQSPAngleListAdv

# Define the parameters for the target function
sigma = 0.5  # Example value for sigma
num_ws_qbs = 3  # Number of workspace qubits
err = 1e-3 # Error tolerance for the angle list generation
init_deg = Alt_DegreeFromError(sigma, err, num_ws_qbs)

# Generate the angle list using the target series coefficients
angle_list, _, _, _ = GetQSPAngleListAdv(sigma, init_deg, err, plot=False, print_desc=False)
